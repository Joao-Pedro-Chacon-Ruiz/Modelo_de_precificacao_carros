# %%
#Importando as bibliotecas
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
from numpy import arange
from numpy import percentile
import numpy as np
from pandas import DataFrame

# %%
dados1 = pd.read_excel('previsao_chuva.xlsx')
dados1.head()
# Out:
#   codigo_estacao       data  hora  temp_inst  temp_max  temp_min  umid_inst  \
# 0           A401 2018-11-06     8       24.6      25.0      24.6         78
# 1           A401 2018-11-06    16       29.9      31.1      29.8         56
# 2           A401 2018-11-06     4       24.7      25.2      24.7         77
# 3           A401 2018-11-06    11       27.3      27.6      26.7         66
# 4           A401 2018-11-06     2       25.1      25.4      25.0         78
#
#    umid_max  umid_min  pto_orvalho_inst  pto_orvalho_max  pto_orvalho_min  \
# 0      78.0      76.0              20.6             20.6             20.4
# 1      62.0      55.0              20.2             22.1             20.2
# 2      80.0      75.0              20.4             21.3             20.2
# 3      72.0      65.0              20.5             21.3             20.3
# 4      78.0      76.0              21.0             21.1             20.8
#
#    pressao  pressao_max  pressao_min  vento_direcao  vento_vel   vento_rajada  \
# 0   1006.7       1006.7       1006.2            0.8       64.0            5.2
# 1   1006.9       1007.6       1006.9            1.8      157.0            6.2
# 2   1006.7       1007.1       1006.7            0.9       58.0            5.2
# 3   1008.9       1008.9       1008.1            1.9       65.0            5.7
# 4   1007.6       1008.1       1007.6            1.2       90.0            5.0
#
#    radiacao  precipitacao
# 0       NaN           0.0
# 1    3389.0           0.0
# 2       NaN           0.0
# 3    1375.0           0.0
# 4       NaN           0.0

# %%
#dados2 = dados1.groupby(['data']).mean()
#dados2.head()

# %%
dados2 = dados1.set_index('data')
dados3 = dados2.transpose()
dados3.head()
# Out:
# data           2018-11-06 2018-11-06 2018-11-06 2018-11-06 2018-11-06  \
# codigo_estacao       A401       A401       A401       A401       A401
# hora                    8         16          4         11          2
# temp_inst            24.6       29.9       24.7       27.3       25.1
# temp_max               25       31.1       25.2       27.6       25.4
# temp_min             24.6       29.8       24.7       26.7         25
#
# data           2018-11-06 2018-11-06 2018-11-06 2018-11-06 2018-11-06  \
# codigo_estacao       A401       A401       A401       A401       A401
# hora                    7          6         22          5         23
# temp_inst            24.9       25.3       25.7       25.4       25.1
# temp_max             25.3       25.5       25.8       25.4       25.8
# temp_min             24.8       25.1       25.5       24.7       25.1
#
# data              ...     2019-11-05 2019-11-05 2019-11-05 2019-11-05  \
# codigo_estacao    ...           A401       A401       A401       A401
# hora              ...             11          7          9         12
# temp_inst         ...           27.4       23.6       24.2       27.6
# temp_max          ...           27.4       24.1       24.2       28.2
# temp_min          ...           26.1       23.6       23.3       27.2
#
# data           2019-11-05 2019-11-05 2019-11-05 2019-11-05 2019-11-05  \
# codigo_estacao       A401       A401       A401       A401       A401
# hora                    8          1          2          4          6
# temp_inst            23.3       25.5       25.2         25       24.1
# temp_max             23.7       25.8       25.6       25.2       24.6
# temp_min             23.3       25.5       25.2         25       24.1
#
# data           2019-11-05
# codigo_estacao       A401
# hora                    3
# temp_inst            25.2
# temp_max             25.4
# temp_min             25.1
#
# [5 rows x 8745 columns]

# %%
dados4 = dados3.loc[['temp_inst', 'pressao','umid_inst', 'precipitacao','radiacao']]
dados5 = dados4.transpose()
dados6.head()
# Out:
#            temp_inst pressao umid_inst precipitacao radiacao
# data
# 2018-11-07      23.8  1008.6        90          0.2      NaN
# 2018-11-07      27.4  1008.2        69          0.2    879.9
# 2018-11-07      23.6  1008.7        88            3      NaN
# 2018-11-08      22.9  1008.8        89          4.6      NaN
# 2018-11-08      24.1  1009.1        85          0.2      NaN

# %%
dados6 = dados5[dados5['precipitacao']>0]
dados7 = np.log(dados6)
dados7.plot(figsize=(12, 6),rot=0);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-633bee18f154> in <module>
#       1 dados6 = dados5[dados5['precipitacao']>0]
# ----> 2 dados7 = np.log(dados6)
#       3 dados7.plot(figsize=(12, 6),rot=0);
#
# AttributeError: 'float' object has no attribute 'log'

# %%
dados8 = dados5[dados5['precipitacao']==0]
dados9 = np.log(dados8)
dados9.plot(figsize=(12, 6),rot=0);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-ee158df96217> in <module>
#       1 dados8 = dados5[dados5['precipitacao']==0]
# ----> 2 dados9 = np.log(dados8)
#       3 dados9.plot(figsize=(12, 6),rot=0);
#
# AttributeError: 'float' object has no attribute 'log'

# %%
def Grafico2Eixos(listax, labelx,  listay1, labely1, listay2, labely2):
    # Vamos agora plotar os resultados como foi pedido: dois eixos
    # Definicao dos objetos figura e eixo       
    fig, ax1 = plt.subplots()
    # plota a lista 1
    ax1.plot(listax, listay1, 'r')
    # dá nome ao eixo x
    ax1.set_xlabel(labelx)
    # dá nome ao eixo y1
    ax1.set_ylabel(labely1, color='r')
    # seta os limites dos eixos x e y
    # faz a cor das marcas no eixo y1 iguais a linha
    for tl in ax1.get_yticklabels():
        tl.set_color('r')    
    # Cria um eixo com valor de y independente, mas com o mesmo x
    ax2 = ax1.twinx()
    # plota a lista 2
    ax2.plot(listax, listay2, 'g')
    # dá nome ao eixo y2
    ax2.set_ylabel(labely2, color='g')
    # seta os limites dos eixos x e y
    #ax2.axis([0,2, 0, max(S)+.5])
    # faz a cor das marcas no eixo iguais a linha
    for tl in ax2.get_yticklabels():
        tl.set_color('g')
    plt.grid(True)
    plt.figure(figsize=(20, 10))
    plt.show()

# %%
tempo = dados6.index
Grafico2Eixos(tempo, 'Tempo (dias)', dados6['precipitacao'],'precipitacao', dados6['pressao'], 'pressao')
